# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('imgs/an_c_and_t.jpeg')

# Plot the originam image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(img)

# Create the sharpening kernel
kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

# Sharpen the image
sharpened_img = cv2.filter2D(img, -1, kernel)

# Plot the sharpened image
plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 16
#      13 kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
#      15 # Sharpen the image
# ---> 16 sharpened_img = cv2.filter20(img, -1, kernel)
#      18 # Plot the sharpened image
#      19 plt.subplot(1, 2, 2)
#
# AttributeError: module 'cv2' has no attribute 'filter20'
