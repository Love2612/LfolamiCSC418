# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('imgs/an_c_and_t.jpeg')

# Plot the originam image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(img)

# Remove noise using a median filter
filtered_img = cv2.medianBlur(img, 5)

# Save the image
cv2.imwrite('imgs/Median-Blur.jpeg', filtered_img)

# Plot the sharpened image
plt.subplot(1, 2, 2)
plt.title("Median Blur")
plt.imshow(filtered_img)
plt.show()
